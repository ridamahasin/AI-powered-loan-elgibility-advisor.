# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\RIDA\Downloads\train.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['ApplicantIncome']
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df[['ApplicantIncome','LoanAmount']]
# Out:
#      ApplicantIncome  LoanAmount
# 0               5849         NaN
# 1               4583       128.0
# 2               3000        66.0
# 3               2583       120.0
# 4               6000       141.0
# ..               ...         ...
# 609             2900        71.0
# 610             4106        40.0
# 611             8072       253.0
# 612             7583       187.0
# 613             4583       133.0
#
# [614 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
#  # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['loan_Amoubt_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  loan_Amoubt_Term   614 non-null    float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 67.3+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  loan_Amoubt_Term
# 0             1.0         Urban           Y             360.0
# ...

# %% [markdown]
# # handling categorical missing values

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# loan_Amoubt_Term      0
# dtype: int64

# %%
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
#categorical data
import seaborn as sns
sns.countplot(df['Gender'])
plt.show()

# %%
sns.countplot(df.Dependents)
plt.show()

# %%
sns.countplot(df.Married)
plt.show()

# %%
sns.distplot(df.CoapplicantIncome)
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\2403132303.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.CoapplicantIncome)

# %%
sns.distplot(df.LoanAmount)
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\471815687.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.LoanAmount)

# %%
sns.countplot(df.Credit_History)
plt.show()

# %%
df['Credit_History']=df['Credit_History'].astype(str)

# %%
sns.countplot(df['Credit_History'])
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term
# 0            1.0         Urban           Y             360.0
# ...

# %%
df['Total_income']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#     Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income
# ...

# %%
df['ApplicantIncomeLog']=np.log(df['ApplicantIncome'])
sns.distplot(df.ApplicantIncomeLog)
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\785394375.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.ApplicantIncomeLog)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income  \
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
df['CoapplicantIncomeLog']=np.log(df['ApplicantIncome'])
sns.distplot(df.CoapplicantIncomeLog)
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\500263189.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.CoapplicantIncomeLog)
# <Axes: xlabel='CoapplicantIncomeLog', ylabel='Density'>

# %%
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income  \
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
df['Loan_Amount_Log']=np.log(df['LoanAmount'])
sns.distplot(df["Loan_Amount_Log"])
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\2315554439.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Loan_Amount_Log"])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income  \
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
df['Loan_Amount_Term_Log']=np.log(df['Loan_Amount_Term'])
sns.distplot(df["Loan_Amount_Term_Log"])
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\1864149640.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Loan_Amount_Term_Log"])

# %%
df['Total_Income_Log']=np.log(df['Total_income'])
sns.distplot(df['Total_Income_Log'])
plt.show()
# Out:
# C:\Users\RIDA\AppData\Local\Temp\ipykernel_11196\1226883614.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_Income_Log'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income  \
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  loan_Amoubt_Term  Total_income  \
# 0            1.0         Urban           Y             360.0        5849.0
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','loan_Amoubt_Term','Loan_Amount_Term','Loan_ID','Total_income','CoapplicantIncomeLog']
df=df.drop(columns=cols,axis=1)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Credit_History  \
# 0   Male      No          0      Graduate            No            1.0
# 1   Male     Yes          1      Graduate            No            1.0
# 2   Male     Yes          0      Graduate           Yes            1.0
# 3   Male     Yes          0  Not Graduate            No            1.0
# 4   Male      No          0      Graduate            No            1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0         Urban           Y            8.674026         4.986426
# 1         Rural           N            8.430109         4.852030
# 2         Urban           Y            8.006368         4.189655
# 3         Urban           Y            7.856707         4.787492
# 4         Urban           Y            8.699515         4.948760
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# ...

# %%
df.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                614 non-null    object
#  1   Married               614 non-null    object
#  2   Dependents            614 non-null    object
#  3   Education             614 non-null    object
#  4   Self_Employed         614 non-null    object
#  5   Credit_History        614 non-null    object
#  6   Property_Area         614 non-null    object
#  7   Loan_Status           614 non-null    object
#  8   ApplicantIncomeLog    614 non-null    float64
#  9   Loan_Amount_Log       614 non-null    float64
#  10  Loan_Amount_Term_Log  600 non-null    float64
#  11  Total_Income_Log      614 non-null    float64
# dtypes: float64(4), object(8)
# memory usage: 57.7+ KB

# %%
df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Credit_History  \
# 0   Male      No          0      Graduate            No            1.0
# 1   Male     Yes          1      Graduate            No            1.0
# 2   Male     Yes          0      Graduate           Yes            1.0
# 3   Male     Yes          0  Not Graduate            No            1.0
# 4   Male      No          0      Graduate            No            1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0         Urban           Y            8.674026         4.986426
# 1         Rural           N            8.430109         4.852030
# 2         Urban           Y            8.006368         4.189655
# 3         Urban           Y            7.856707         4.787492
# 4         Urban           Y            8.699515         4.948760
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.886104          8.674026
# 1              5.886104          8.714568
# ...

# %% [markdown]
# # get_dummies-converts a categorical data into a dummy or indicator variable, which are numerical representations.

# %%
d1=pd.get_dummies(df['Gender'],drop_first=True)
d2=pd.get_dummies(df['Married'],drop_first=True)
d3=pd.get_dummies(df['Dependents'],drop_first=True)
d4=pd.get_dummies(df['Education'],drop_first=True)
d5=pd.get_dummies(df['Self_Employed'],drop_first=True)
d6=pd.get_dummies(df['Property_Area'],drop_first=True)

#concating columns to dataframe
df1=pd.concat([df,d1,d2,d3,d4,d5,d6],axis=1)
df=df1
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
df=df.drop(columns=cols,axis=1)

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0            1.0           Y            8.674026         4.986426
# 1            1.0           N            8.430109         4.852030
# 2            1.0           Y            8.006368         4.189655
# 3            1.0           Y            7.856707         4.787492
# 4            1.0           Y            8.699515         4.948760
#
#    Loan_Amount_Term_Log  Total_Income_Log  Male    Yes      1      2     3+  \
# 0              5.886104          8.674026  True  False  False  False  False
# 1              5.886104          8.714568  True   True   True  False  False
# 2              5.886104          8.006368  True   True  False  False  False
# 3              5.886104          8.505323  True   True  False  False  False
# 4              5.886104          8.699515  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# ...

# %% [markdown]
# # test data

# %%
test=pd.read_csv(r"C:\Users\RIDA\Downloads\test.csv")

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
#fiLLing numerical missing values
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test['LoanAmount']=test['LoanAmount'].fillna(test['LoanAmount'].mean())

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#Loan_amount_term 
test['Loan_Amount_Term']=test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mean())

#credit_history
test['Credit_History']=test['Credit_History'].fillna(test['Credit_History'].mean())

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0        1.000000         Urban
# 1        1.000000         Urban
# 2        1.000000         Urban
# ...

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
#filling categorical missing data
test['Gender']=test['Gender'].fillna(test['Gender'].mode()[0])     
test['Dependents']=test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Self_Employed']=test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

# %%
test.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test['Total_income']=test['ApplicantIncome']+test['CoapplicantIncome']

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_income
# 0        1.000000         Urban          5720
# 1        1.000000         Urban          4576
# ...

# %%
#applying log transformations to the attributes
test['ApplicantIncomeLog']=np.log(test['ApplicantIncome'])
test['CoapplicantIncomeLog']=np.log(test['CoapplicantIncome'])
test['LoanAmountLog']=np.log(test['LoanAmount'])
test['Loan_Amount_Term_Log']=np.log(test['Loan_Amount_Term'])
test['Total_Income_Log']=np.log(test['Total_income'])
# Out:
# c:\Users\RIDA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\RIDA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  Total_income  ApplicantIncomeLog  \
# 0        1.000000         Urban          5720            8.651724
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_income','Loan_ID','CoapplicantIncomeLog']
test=test.drop(columns=cols,axis=1)

# %%
test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male     Yes          0      Graduate            No        1.000000
# 1   Male     Yes          1      Graduate            No        1.000000
# 2   Male     Yes          2      Graduate            No        1.000000
# 3   Male     Yes          2      Graduate            No        0.825444
# 4   Male      No          0  Not Graduate            No        1.000000
#
#   Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0         Urban            8.651724       4.700480              5.886104
# 1         Urban            8.031385       4.836282              5.886104
# 2         Urban            8.517193       5.337538              5.886104
# 3         Urban            7.757906       4.605170              5.886104
# 4         Urban            8.094378       4.356709              5.886104
#
#    Total_Income_Log
# 0          8.651724
# 1          8.428581
# 2          8.824678
# ...

# %%
t1=pd.get_dummies(test['Gender'],drop_first=True)
t2=pd.get_dummies(test['Married'],drop_first=True)
t3=pd.get_dummies(test['Dependents'],drop_first=True)
t4=pd.get_dummies(test['Education'],drop_first=True)
t5=pd.get_dummies(test['Self_Employed'],drop_first=True)
t6=pd.get_dummies(test['Property_Area'],drop_first=True)
df1=pd.concat([test,t1,t2,t3,t4,t5,t6],axis=1)
test=df1

# %%
test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male     Yes          0      Graduate            No        1.000000
# 1   Male     Yes          1      Graduate            No        1.000000
# 2   Male     Yes          2      Graduate            No        1.000000
# 3   Male     Yes          2      Graduate            No        0.825444
# 4   Male      No          0  Not Graduate            No        1.000000
#
#   Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0         Urban            8.651724       4.700480              5.886104
# 1         Urban            8.031385       4.836282              5.886104
# 2         Urban            8.517193       5.337538              5.886104
# 3         Urban            7.757906       4.605170              5.886104
# 4         Urban            8.094378       4.356709              5.886104
#
#    Total_Income_Log  Male    Yes      1      2     3+  Not Graduate    Yes  \
# ...

# %%
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
test=test.drop(columns=cols,axis=1)

# %%
test.head()
# Out:
#    Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0        1.000000            8.651724       4.700480              5.886104
# 1        1.000000            8.031385       4.836282              5.886104
# 2        1.000000            8.517193       5.337538              5.886104
# 3        0.825444            7.757906       4.605170              5.886104
# 4        1.000000            8.094378       4.356709              5.886104
#
#    Total_Income_Log  Male    Yes      1      2     3+  Not Graduate    Yes  \
# 0          8.651724  True   True  False  False  False         False  False
# 1          8.428581  True   True   True  False  False         False  False
# 2          8.824678  True   True  False   True  False         False  False
# 3          8.494129  True   True  False   True  False         False  False
# 4          8.094378  True  False  False  False  False          True  False
#
#    Semiurban  Urban
# 0      False   True
# 1      False   True
# ...

# %% [markdown]
# # split datasets

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  Loan_Amount_Log  \
# 0            1.0           Y            8.674026         4.986426
# 1            1.0           N            8.430109         4.852030
# 2            1.0           Y            8.006368         4.189655
# 3            1.0           Y            7.856707         4.787492
# 4            1.0           Y            8.699515         4.948760
#
#    Loan_Amount_Term_Log  Total_Income_Log  Male    Yes      1      2     3+  \
# 0              5.886104          8.674026  True  False  False  False  False
# 1              5.886104          8.714568  True   True   True  False  False
# 2              5.886104          8.006368  True   True  False  False  False
# 3              5.886104          8.505323  True   True  False  False  False
# 4              5.886104          8.699515  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# ...

# %%
#specify input and output attributes
#x=df.drop(columns=df['Loan_Status'],axis=1)
y=df['Loan_Status']

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
x=df.drop(columns=['Loan_Status'],axis=1)
x
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Loan_Amount_Term_Log  \
# 0              1.0            8.674026         4.986426              5.886104
# 1              1.0            8.430109         4.852030              5.886104
# 2              1.0            8.006368         4.189655              5.886104
# 3              1.0            7.856707         4.787492              5.886104
# 4              1.0            8.699515         4.948760              5.886104
# ..             ...                 ...              ...                   ...
# 609            1.0            7.972466         4.262680              5.886104
# 610            1.0            8.320205         3.688879              5.192957
# 611            1.0            8.996157         5.533389              5.886104
# 612            1.0            8.933664         5.231109              5.886104
# 613            0.0            8.430109         4.890349              5.886104
#
# ...

# %%
x
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Loan_Amount_Term_Log  \
# 0              1.0            8.674026         4.986426              5.886104
# 1              1.0            8.430109         4.852030              5.886104
# 2              1.0            8.006368         4.189655              5.886104
# 3              1.0            7.856707         4.787492              5.886104
# 4              1.0            8.699515         4.948760              5.886104
# ..             ...                 ...              ...                   ...
# 609            1.0            7.972466         4.262680              5.886104
# 610            1.0            8.320205         3.688879              5.192957
# 611            1.0            8.996157         5.533389              5.886104
# 612            1.0            8.933664         5.231109              5.886104
# 613            0.0            8.430109         4.890349              5.886104
#
# ...

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x , y, test_size=0.25, random_state = 42)

# %%
x_train.head()
# Out:
#     Credit_History  ApplicantIncomeLog  Loan_Amount_Log  Loan_Amount_Term_Log  \
# 92             1.0            8.093462         4.394449              5.886104
# 304            1.0            8.294050         4.941642              5.886104
# 68             1.0            8.867850         4.828314              4.094345
# 15             1.0            8.507143         4.828314              5.886104
# 211            0.0            8.140316         4.852030              5.886104
#
#      Total_Income_Log  Male    Yes      1      2     3+  Not Graduate    Yes  \
# 92           8.535622  True   True  False   True  False          True  False
# 304          8.779557  True  False  False  False  False         False  False
# 68           8.867850  True   True  False  False   True          True   True
# 15           8.507143  True  False  False  False  False         False  False
# 211          8.451053  True   True  False  False   True         False  False
#
#      Semiurban  Urban
# ...

# %%
x_test.head()
# Out:
#          Credit_History  ApplicantIncomeLog  Loan_Amount_Log  \
# 350                 1.0            9.114160         5.429346
# 377  0.8421985815602837            8.368693         4.867534
# 163                 1.0            8.334952         5.062595
# 609                 1.0            7.972466         4.262680
# 132                 1.0            7.907652         4.248495
#
#      Loan_Amount_Term_Log  Total_Income_Log   Male    Yes      1      2  \
# 350              5.886104          9.114160   True   True  False  False
# 377              5.886104          8.368693   True   True  False  False
# 163              5.886104          8.633019   True   True  False   True
# 609              5.886104          7.972466  False  False  False  False
# 132              5.886104          7.907652   True  False  False  False
#
#         3+  Not Graduate    Yes  Semiurban  Urban
# 350  False         False  False       True  False
# 377  False         False  False       True  False
# ...

# %%
y_train.head()
# Out:
# 92     Y
# 304    Y
# 68     Y
# 15     Y
# 211    N
# Name: Loan_Status, dtype: object

# %%
y_test.head()
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
# Name: Loan_Status, dtype: object

# %% [markdown]
# # model training
# # randomforest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # random forest - is an ensemble model that combines prediction of many decision trees & output will be based upto the majority voting of trees

# %%
print("Accuracy is" ,model.score(x_test,y_test)*100)
# Out:
# Accuracy is 79.22077922077922

# %% [markdown]
# # Decision Tree - decision tree is a model that makes decision by recursively splitting data based on the features ,values.

# %%
from sklearn.tree import DecisionTreeClassifier
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
print("Accuracy is", model2.score(x_test,y_test)*100)
# Out:
# Accuracy is 72.07792207792207

# %% [markdown]
# # logistic regression - predicts probability of a categorical or binary outcome based on input features using sigmanoid function

# %%
print(x_train.isnull().sum())
print(x_test.isnull().sum())
# Out:
# Credit_History           0
# ApplicantIncomeLog       0
# Loan_Amount_Log          0
# Loan_Amount_Term_Log    11
# Total_Income_Log         0
# Male                     0
# Yes                      0
# 1                        0
# 2                        0
# 3+                       0
# Not Graduate             0
# Yes                      0
# Semiurban                0
# Urban                    0
# dtype: int64
# Credit_History          0
# ApplicantIncomeLog      0
# Loan_Amount_Log         0
# Loan_Amount_Term_Log    3
# Total_Income_Log        0
# Male                    0
# Yes                     0
# 1                       0
# 2                       0
# 3+                      0
# Not Graduate            0
# Yes                     0
# Semiurban               0
# Urban                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Numeric columns
num_cols = x_train.select_dtypes(include='number').columns

imputer = SimpleImputer(strategy='mean')
x_train[num_cols] = imputer.fit_transform(x_train[num_cols])
x_test[num_cols] = imputer.transform(x_test[num_cols])

# Optional: For categorical columns
cat_cols = x_train.select_dtypes(include='object').columns
cat_imputer = SimpleImputer(strategy='most_frequent')
x_train[cat_cols] = cat_imputer.fit_transform(x_train[cat_cols])
x_test[cat_cols] = cat_imputer.transform(x_test[cat_cols])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in cat_cols:
    x_train[col] = le.fit_transform(x_train[col])
    x_test[col] = le.transform(x_test[col])

# %%
from sklearn.linear_model import LogisticRegression

model3 = LogisticRegression(max_iter=1000)
model3.fit(x_train, y_train)

accuracy = model3.score(x_test, y_test) * 100
print("Accuracy is:", accuracy)
# Out:
# Accuracy is: 77.27272727272727

# %%
# model save
import pickle
file=open("model.pkl",'wb')
pickle.dump(model,file)
